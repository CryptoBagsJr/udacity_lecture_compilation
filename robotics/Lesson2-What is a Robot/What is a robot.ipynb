# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # 1. What is a Robot?

# %%
YouTubeVideo('MooPT63kaMc', width=960, height=540)

# %% [markdown]
# # 2. Perception

# %%
YouTubeVideo('BofRh5BrBDc', width=960, height=540)

# %% [markdown]
# # 3. Decision Making

# %%
YouTubeVideo('TQtZx-5xyBk', width=960, height=540)

# %% [markdown]
# # 4. Action!

# %%
YouTubeVideo('P-tzy1C7bJU', width=960, height=540)

# %% [markdown]
# # 5. Essential Elements of Robotics
