# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # 1. The World of Robotics

# %%
YouTubeVideo('J_lXNPRIwag', width=960, height=540)

# %% [markdown]
# # 2. Meet Your Instructors

# %%
YouTubeVideo('3Zp2ukfskyE', width=960, height=540)

# %% [markdown]
# # 3. Projects You Will Build

# %%
YouTubeVideo('inT5Ns2DvAs', width=960, height=540)

# %% [markdown]
# # 4. Student Support
#
# # 5. Deadline Policy
