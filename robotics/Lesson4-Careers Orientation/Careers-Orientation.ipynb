# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # 1. Meet the Careers Team

# %%
YouTubeVideo('FLvRSIfVu5U', width=960, height=540)

# %% [markdown]
# # 2. Your Udacity Profile

# %% [markdown]
# # 3. Careers in Robotics

# %%
YouTubeVideo('HS8ALYfDgJw', width=960, height=540)

# %% [markdown]
# # 4. Design Review

# %%
YouTubeVideo('IlXkmoY_8Vw', width=960, height=540)
