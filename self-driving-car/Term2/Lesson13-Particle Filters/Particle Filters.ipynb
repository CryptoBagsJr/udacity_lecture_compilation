# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # 1. Filed Trip

# %%
YouTubeVideo('2ocy_7PJtfA', width=960, height=540)

# %% [markdown]
# # 2. State Space

# %%
YouTubeVideo('G7nvigL0aDw', width=960, height=540)

# %%
YouTubeVideo('oyw7WEHMvVY', width=960, height=540)

# %% [markdown]
# # 3. Quiz: Belief Modality

# %%
YouTubeVideo('5vdbYPc7tWw', width=960, height=540)

# %%
YouTubeVideo('NhKyyhNl70A', width=960, height=540)

# %% [markdown]
# # 4. Quiz: Efficiency

# %%
YouTubeVideo('7CNEY8lRrGE', width=960, height=540)

# %%
YouTubeVideo('rA8ZpMR6yXM', width=960, height=540)

# %% [markdown]
# # 5. Quiz: Exact or Approximate

# %%
YouTubeVideo('WKlm2aO2QGY', width=960, height=540)

# %%
YouTubeVideo('1N3_RnTDFqU', width=960, height=540)

# %% [markdown]
# # 6. Particle Filters

# %%
YouTubeVideo('4S-sx5_cmLU', width=960, height=540)

# %% [markdown]
# # 7. Using Robot Class

# %%
YouTubeVideo('1hgVZtRIjFU', width=960, height=540)

# %% [markdown]
# # 8. Robot Class Details

# %%
YouTubeVideo('ZFqEh8JylvI', width=960, height=540)
