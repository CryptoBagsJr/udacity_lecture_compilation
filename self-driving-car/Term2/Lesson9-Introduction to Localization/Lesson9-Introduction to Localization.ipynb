# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # 1. Lesson Introduction

# %%
YouTubeVideo('lwmXQ-kxU3s', width=960, height=540)

# %% [markdown]
# # 2. Localization Intuition Quiz

# %%
YouTubeVideo('mVCSCU67D80', width=960, height=540)

# %% [markdown]
# ## QUIZ QUESTION
# If the structure you saw in the video were in front of you, where would you be?
# - (A) New York City, USA
# - (B) Sao Paulo, Brazil
# - (C) Paris, France
# - (D) Udacity Headquarters in Mountain View, California
#
# Answer: (C)

# %% [markdown]
# # 3. Localization Intuition Explanation

# %%
YouTubeVideo('alIgWnGBUS8', width=960, height=540)

# %% [markdown]
# # 4. Localizing a Self Driving Car

# %%
YouTubeVideo('U-uDtVgezcE', width=960, height=540)

# %%
# 5. Overview of the Lessons
